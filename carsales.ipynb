# %%
# Dependencies
import requests
import json
import pymongo
from config import api_key

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.carsDB

# %%
# URL for GET requests to retrieve vehicle data
new_url = "https://marketcheck-prod.apigee.net/v2/popular/cars?api_key=8U9TGE7fOstu20Y4w6kNxAY9OqeYBZ7N&car_type=new"

# %%
used_url = "https://marketcheck-prod.apigee.net/v2/popular/cars?api_key=8U9TGE7fOstu20Y4w6kNxAY9OqeYBZ7N&car_type=used"

# %%
ca_url = "https://marketcheck-prod.apigee.net/v2/popular/cars?api_key=8U9TGE7fOstu20Y4w6kNxAY9OqeYBZ7N&car_type=new&state=CA"

# %%
ny_url = "https://marketcheck-prod.apigee.net/v2/popular/cars?api_key=8U9TGE7fOstu20Y4w6kNxAY9OqeYBZ7N&car_type=new&state=NY"

# %%
kia_url = "https://marketcheck-prod.apigee.net/v2/search/car/active?api_key=8U9TGE7fOstu20Y4w6kNxAY9OqeYBZ7N&car_type=new&year=2019,2018,2017,2016,2015,2014&make=kia&model=rio"

# %%
chevy_url = "https://marketcheck-prod.apigee.net/v2/search/car/active?api_key=8U9TGE7fOstu20Y4w6kNxAY9OqeYBZ7N&car_type=new&year=2019,2018,2017,2016,2015,2014&make=chevrolet&model=cruze"

# %%
honda_url = "https://marketcheck-prod.apigee.net/v2/search/car/active?api_key=8U9TGE7fOstu20Y4w6kNxAY9OqeYBZ7N&car_type=new&year=2019,2018,2017,2016,2015,2014&make=honda&make=accord"

# %%
toyota_url = "https://marketcheck-prod.apigee.net/v2/search/car/active?api_key=8U9TGE7fOstu20Y4w6kNxAY9OqeYBZ7N&car_type=new&year=2019,2018,2017,2016,2015,2014&make=toyota&model=camry"

# %%
lexus_url = "https://marketcheck-prod.apigee.net/v2/search/car/active?api_key=8U9TGE7fOstu20Y4w6kNxAY9OqeYBZ7N&car_type=new&year=2019,2018,2017,2016,2015,2014&make=lexus&model=es"

# %%
mercedes_url = "https://marketcheck-prod.apigee.net/v2/search/car/active?api_key=8U9TGE7fOstu20Y4w6kNxAY9OqeYBZ7N&car_type=new&year=2019,2018,2017,2016,2015,2014&make=mercedes-benz&make=c-class"

# %%
# Print the response object to the console
print(requests.get(new_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(used_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(ca_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(ny_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(kia_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(chevy_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(honda_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(toyota_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(lexus_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(mercedes_url))
# Out:
# <Response [200]>

# %%
# Retrieving data and converting it into JSON
print(requests.get(new_url).json())
# Out:
# [{'country': 'us', 'inventory_type': 'new', 'count': 102963, 'make': 'Ford', 'model': 'F-150', 'price_stats': {'geometric_mean': 43059, 'listings_count': 98390, 'min': 6250, 'median': 41831, 'population_standard_deviation': 26503, 'variance': 702382605, 'max': 7502019, 'mean': 44459, 'trimmed_mean': 43343, 'standard_deviation': 26503, 'iqr': 13504}, 'miles_stats': {'geometric_mean': 49, 'listings_count': 16935, 'min': 1, 'median': 16, 'population_standard_deviation': 8892, 'variance': 79076485, 'max': 730469, 'mean': 1381, 'trimmed_mean': 409, 'standard_deviation': 8892, 'iqr': 743}, 'dom_stats': {'geometric_mean': 86, 'listings_count': 102963, 'min': 1, 'median': 96, 'population_standard_deviation': 102, 'variance': 10365, 'max': 1464, 'mean': 126, 'trimmed_mean': 114, 'standard_deviation': 102, 'iqr': 140}}, {'country': 'us', 'inventory_type': 'new', 'count': 89329, 'make': 'Chevrolet', 'model': 'Silverado 1500', 'price_stats': {'geometric_mean': 40644, 'listings_count': 88061, 'mi
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(used_url).json())
# Out:
# [{'country': 'us', 'inventory_type': 'used', 'count': 102767, 'make': 'Ford', 'model': 'F-150', 'price_stats': {'geometric_mean': 22934, 'listings_count': 90156, 'min': 499, 'median': 26450, 'population_standard_deviation': 11368, 'variance': 129241702, 'max': 409905, 'mean': 25821, 'trimmed_mean': 25545, 'standard_deviation': 11368, 'iqr': 14195}, 'miles_stats': {'geometric_mean': 49392, 'listings_count': 98269, 'min': 1, 'median': 60062, 'population_standard_deviation': 57017, 'variance': 3250942079, 'max': 1406720, 'mean': 74231, 'trimmed_mean': 67610, 'standard_deviation': 57017, 'iqr': 75920}, 'dom_stats': {'geometric_mean': 68, 'listings_count': 102767, 'min': 1, 'median': 80, 'population_standard_deviation': 158, 'variance': 24894, 'max': 2429, 'mean': 124, 'trimmed_mean': 96, 'standard_deviation': 158, 'iqr': 119}}, {'country': 'us', 'inventory_type': 'used', 'count': 75449, 'make': 'Chevrolet', 'model': 'Silverado 1500', 'price_stats': {'geometric_mean': 22927, 'listings_cou
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(ca_url).json())
# Out:
# [{'country': 'us', 'inventory_type': 'new', 'state': 'CA', 'count': 11037, 'make': 'Honda', 'model': 'Accord', 'price_stats': {'geometric_mean': 27330, 'listings_count': 9692, 'min': 16509, 'median': 27110, 'population_standard_deviation': 3192, 'variance': 10185698, 'max': 63255, 'mean': 27504, 'trimmed_mean': 27137, 'standard_deviation': 3192, 'iqr': 3900}, 'miles_stats': {'geometric_mean': 6, 'listings_count': 3072, 'min': 1, 'median': 5, 'population_standard_deviation': 4101, 'variance': 16814922, 'max': 202430, 'mean': 154, 'trimmed_mean': 6, 'standard_deviation': 4101, 'iqr': 7}, 'dom_stats': {'geometric_mean': 50, 'listings_count': 11037, 'min': 1, 'median': 54, 'population_standard_deviation': 82, 'variance': 6660, 'max': 664, 'mean': 81, 'trimmed_mean': 67, 'standard_deviation': 82, 'iqr': 81}}, {'country': 'us', 'inventory_type': 'new', 'state': 'CA', 'count': 10732, 'make': 'Toyota', 'model': 'Camry', 'price_stats': {'geometric_mean': 27706, 'listings_count': 10312, 'min':
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(ny_url).json())
# Out:
# [{'country': 'us', 'inventory_type': 'new', 'state': 'NY', 'count': 6661, 'make': 'Honda', 'model': 'CR-V', 'price_stats': {'geometric_mean': 30170, 'listings_count': 6393, 'min': 17000, 'median': 29845, 'population_standard_deviation': 2079, 'variance': 4320913, 'max': 35345, 'mean': 30244, 'trimmed_mean': 30342, 'standard_deviation': 2079, 'iqr': 2500}, 'miles_stats': {'geometric_mean': 5, 'listings_count': 1144, 'min': 1, 'median': 5, 'population_standard_deviation': 319, 'variance': 101641, 'max': 5895, 'mean': 35, 'trimmed_mean': 5, 'standard_deviation': 319, 'iqr': 5}, 'dom_stats': {'geometric_mean': 42, 'listings_count': 6661, 'min': 1, 'median': 46, 'population_standard_deviation': 57, 'variance': 3221, 'max': 1106, 'mean': 62, 'trimmed_mean': 52, 'standard_deviation': 57, 'iqr': 57}}, {'country': 'us', 'inventory_type': 'new', 'state': 'NY', 'count': 5226, 'make': 'Chevrolet', 'model': 'Equinox', 'price_stats': {'geometric_mean': 27349, 'listings_count': 5066, 'min': 15999, 
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(kia_url).json())
# Out:
# {'num_found': 294, 'listings': [{'id': '3KPA24AB6KE243067-8b16dc72-74cb', 'vin': '3KPA24AB6KE243067', 'heading': 'New 2019 Kia Rio S', 'price': 16638, 'msrp': 17115, 'data_source': 'mc', 'vdp_url': 'https://www.findlayauto.com/inventory/new-2019-kia-rio-s-fwd-4d-sedan-3kpa24ab6ke243067', 'carfax_1_owner': False, 'carfax_clean_title': False, 'exterior_color': 'Gray', 'interior_color': 'Gray', 'dom': 229, 'dom_180': 229, 'dom_active': 229, 'seller_type': 'dealer', 'inventory_type': 'new', 'stock_no': 'K3352', 'last_seen_at': 1586316756, 'last_seen_at_date': '2020-04-08T03:32:36.000Z', 'scraped_at': 1571951916, 'scraped_at_date': '2019-10-24T21:18:36.000Z', 'first_seen_at': 1571951916, 'first_seen_at_date': '2019-10-24T21:18:36.000Z', 'ref_price': 17115, 'ref_price_dt': 1571827351, 'ref_miles': 0, 'source': 'findlayauto.com', 'media': {'photo_links': ['https://17fb6cb89e9b2aa65003-e4bfb60925a674e5aec5c00bf34cdd3a.ssl.cf1.rackcdn.com/3KPA24AB6KE243067/eb81b0088613c499f1f4b6df718d9ec6.jpg
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(chevy_url).json())
# Out:
# {'num_found': 843, 'listings': [{'id': '3G1BE6SM9KS554770-576592ed-0b0b', 'vin': '3G1BE6SM9KS554770', 'heading': 'New 2019 Chevrolet Cruze LT', 'price': 20273, 'msrp': 25885, 'data_source': 'mc', 'vdp_url': 'https://www.marinechevy.com/inventory/new-2019-chevrolet-cruze-lt-fwd-4d-hatchback-3g1be6sm9ks554770', 'carfax_1_owner': False, 'carfax_clean_title': False, 'exterior_color': 'Red', 'interior_color': 'Black', 'dom': 361, 'dom_180': 234, 'dom_active': 35, 'seller_type': 'dealer', 'inventory_type': 'new', 'stock_no': 'JP168', 'last_seen_at': 1586317798, 'last_seen_at_date': '2020-04-08T03:49:58.000Z', 'scraped_at': 1586145584, 'scraped_at_date': '2020-04-06T03:59:44.000Z', 'first_seen_at': 1586145584, 'first_seen_at_date': '2020-04-06T03:59:44.000Z', 'ref_price': 0, 'ref_miles': 0, 'source': 'marinechevy.com', 'media': {'photo_links': ['https://a7a2ed6e28a1df7f59ba-c9f9f4e6a33c42cb8362a5fe294da325.ssl.cf1.rackcdn.com/3G1BE6SM9KS554770/426f6b528844ea10492146b07f644c2c.jpg', 'https:/
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(honda_url).json())
# Out:
# {'num_found': 34357, 'listings': [{'id': '1HGCV2F37KA009899-42ed82ee-2821', 'vin': '1HGCV2F37KA009899', 'heading': '2019 Honda Accord Sport 2.0T', 'price': 31630, 'msrp': 31630, 'data_source': 'mc', 'vdp_url': 'https://www.hondaofhollywood.com/new-Hollywood+-2019-Honda-Accord-Sport+20T-1HGCV2F37KA009899', 'carfax_1_owner': True, 'carfax_clean_title': False, 'exterior_color': 'Crystal Black Pearl', 'interior_color': 'Black', 'dom': 417, 'dom_180': 231, 'dom_active': 231, 'seller_type': 'dealer', 'inventory_type': 'new', 'stock_no': '2190696', 'last_seen_at': 1586318186, 'last_seen_at_date': '2020-04-08T03:56:26.000Z', 'scraped_at': 1566503972, 'scraped_at_date': '2019-08-22T19:59:32.000Z', 'first_seen_at': 1566503972, 'first_seen_at_date': '2019-08-22T19:59:32.000Z', 'ref_price': 0, 'ref_miles': 0, 'source': 'hondaofhollywood.com', 'model_code': 'CV2F3KJW', 'media': {'photo_links': ['https://www.hondaofhollywood.com/assets/stock/colormatched_01/white/640/cc_2019hoc01_01_640/cc_2019hoc
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(toyota_url).json())
# Out:
# {'num_found': 971, 'listings': [{'id': '4T1BF1FK0FU905194-5dca7ce9-813e', 'vin': '4T1BF1FK0FU905194', 'heading': '2015 Toyota Camry XLE Sedan', 'price': 30754, 'msrp': 30754, 'data_source': 'mc', 'vdp_url': 'https://www.berkshirehathawayautomotive.com/new/Toyota/2015-Toyota-Camry-cb0f0e9c0a0d04fe6e7f22d6b1a41836.htm', 'carfax_1_owner': True, 'carfax_clean_title': False, 'exterior_color': 'Cosmic Gray', 'interior_color': 'Parch Ec', 'dom': 29, 'dom_180': 29, 'dom_active': 29, 'seller_type': 'dealer', 'inventory_type': 'new', 'stock_no': 'FU905194', 'last_seen_at': 1586317552, 'last_seen_at_date': '2020-04-08T03:45:52.000Z', 'scraped_at': 1583966928, 'scraped_at_date': '2020-03-11T22:48:48.000Z', 'first_seen_at': 1583966928, 'first_seen_at_date': '2020-03-11T22:48:48.000Z', 'ref_price': 0, 'ref_miles': 0, 'source': 'berkshirehathawayautomotive.com', 'model_code': '2540', 'availability_status': 'Available', 'financing_options': [{'loan_term': 72, 'loan_apr': 4.64, 'down_payment': 3075, 
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(lexus_url).json())
# Out:
# {'num_found': 617, 'listings': [{'id': 'JTHB21B11K2030161-80c4e53e-fe7c', 'vin': 'JTHB21B11K2030161', 'heading': 'New 2019 Lexus ES ES 300h Luxury FWD', 'price': 51844, 'miles': 25, 'data_source': 'mc', 'vdp_url': 'https://www.lacarguy.com/inventory/new-2019-lexus-es-es-300h-luxury-fwd-fwd-4dr-car-jthb21b11k2030161', 'carfax_1_owner': False, 'carfax_clean_title': False, 'exterior_color': 'EMINENT WHITE PEARL', 'interior_color': 'BLACK W/ LINEAR ESPRESSO WOOD', 'dom': 419, 'dom_180': 419, 'dom_active': 419, 'seller_type': 'dealer', 'inventory_type': 'new', 'stock_no': '19EH1139', 'last_seen_at': 1586316279, 'last_seen_at_date': '2020-04-08T03:24:39.000Z', 'scraped_at': 1569957461, 'scraped_at_date': '2019-10-01T19:17:41.000Z', 'first_seen_at': 1569957461, 'first_seen_at_date': '2019-10-01T19:17:41.000Z', 'ref_price': 0, 'ref_miles': 0, 'source': 'lacarguy.com', 'media': {'photo_links': ['https://9ec6b0feb4b336c0bb22-298613918ac10dd8380d273c03a66c3b.ssl.cf1.rackcdn.com/JTHB21B11K203016
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(mercedes_url).json())
# Out:
# {'num_found': 15108, 'listings': [{'id': 'WD4FF1CD8KT009677-ce25acce-377d', 'vin': 'WD4FF1CD8KT009677', 'heading': '2019 Mercedes-Benz Sprinter 2500 High Roof V6', 'price': 62579, 'miles': 4, 'msrp': 62579, 'data_source': 'mc', 'vdp_url': 'https://www.newcountrymercedes.com/new/Mercedes-Benz/2019-Mercedes-Benz-Sprinter+2500-Hartford-CT-06120-133307260a0e0ae7430c93ed25709194.htm', 'carfax_1_owner': False, 'carfax_clean_title': False, 'exterior_color': 'Gray', 'dom': 14, 'dom_180': 14, 'dom_active': 14, 'seller_type': 'dealer', 'inventory_type': 'new', 'stock_no': 'S1570', 'last_seen_at': 1586317895, 'last_seen_at_date': '2020-04-08T03:51:35.000Z', 'scraped_at': 1585246047, 'scraped_at_date': '2020-03-26T18:07:27.000Z', 'first_seen_at': 1585246047, 'first_seen_at_date': '2020-03-26T18:07:27.000Z', 'ref_price': 0, 'ref_miles': 0, 'source': 'newcountrymercedes.com', 'financing_options': [{'loan_term': 60, 'loan_apr': 3.9}], 'media': {'photo_links': ['https://pictures.dealer.com/n/newcoun
# ...

# %%
# Pretty Print the output of the JSON
new_response = requests.get(new_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "listings": [
#         {
#             "build": {
#                 "body_type": "Sedan",
#                 "cylinders": 4,
#                 "doors": 4,
#                 "drivetrain": "RWD",
#                 "engine": "2.0L I4",
#                 "engine_block": "I",
#                 "engine_size": 2,
#                 "fuel_type": "Premium Unleaded",
#                 "made_in": "USA",
#                 "make": "Mercedes-Benz",
#                 "model": "C-Class",
#                 "overall_height": "184.5",
#                 "overall_width": "56.9",
#                 "std_seating": "5",
#                 "transmission": "Automatic",
#                 "trim": "C300",
#                 "vehicle_type": "Car",
#                 "year": 2016
#             },
#             "carfax_1_owner": false,
#             "carfax_clean_title": false,
#             "data_source": "mc",
#             "dealer": {
#                 "city": "Redwood City",
# ...

# %%
# Pretty Print the output of the JSON
used_urlresponse = requests.get(used_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "listings": [
#         {
#             "build": {
#                 "body_type": "Sedan",
#                 "cylinders": 4,
#                 "doors": 4,
#                 "drivetrain": "RWD",
#                 "engine": "2.0L I4",
#                 "engine_block": "I",
#                 "engine_size": 2,
#                 "fuel_type": "Premium Unleaded",
#                 "made_in": "USA",
#                 "make": "Mercedes-Benz",
#                 "model": "C-Class",
#                 "overall_height": "184.5",
#                 "overall_width": "56.9",
#                 "std_seating": "5",
#                 "transmission": "Automatic",
#                 "trim": "C300",
#                 "vehicle_type": "Car",
#                 "year": 2016
#             },
#             "carfax_1_owner": false,
#             "carfax_clean_title": false,
#             "data_source": "mc",
#             "dealer": {
#                 "city": "Redwood City",
# ...

# %%
# Pretty Print the output of the JSON
ca_response = requests.get(ca_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "listings": [
#         {
#             "build": {
#                 "body_type": "Sedan",
#                 "cylinders": 4,
#                 "doors": 4,
#                 "drivetrain": "RWD",
#                 "engine": "2.0L I4",
#                 "engine_block": "I",
#                 "engine_size": 2,
#                 "fuel_type": "Premium Unleaded",
#                 "made_in": "USA",
#                 "make": "Mercedes-Benz",
#                 "model": "C-Class",
#                 "overall_height": "184.5",
#                 "overall_width": "56.9",
#                 "std_seating": "5",
#                 "transmission": "Automatic",
#                 "trim": "C300",
#                 "vehicle_type": "Car",
#                 "year": 2016
#             },
#             "carfax_1_owner": false,
#             "carfax_clean_title": false,
#             "data_source": "mc",
#             "dealer": {
#                 "city": "Redwood City",
# ...

# %%
# Pretty Print the output of the JSON
ny_response = requests.get(ny_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "listings": [
#         {
#             "build": {
#                 "body_type": "Sedan",
#                 "cylinders": 4,
#                 "doors": 4,
#                 "drivetrain": "RWD",
#                 "engine": "2.0L I4",
#                 "engine_block": "I",
#                 "engine_size": 2,
#                 "fuel_type": "Premium Unleaded",
#                 "made_in": "USA",
#                 "make": "Mercedes-Benz",
#                 "model": "C-Class",
#                 "overall_height": "184.5",
#                 "overall_width": "56.9",
#                 "std_seating": "5",
#                 "transmission": "Automatic",
#                 "trim": "C300",
#                 "vehicle_type": "Car",
#                 "year": 2016
#             },
#             "carfax_1_owner": false,
#             "carfax_clean_title": false,
#             "data_source": "mc",
#             "dealer": {
#                 "city": "Redwood City",
# ...

# %%
# Pretty Print the output of the JSON
kia_response = requests.get(kia_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "listings": [
#         {
#             "build": {
#                 "body_type": "Sedan",
#                 "cylinders": 4,
#                 "doors": 4,
#                 "drivetrain": "RWD",
#                 "engine": "2.0L I4",
#                 "engine_block": "I",
#                 "engine_size": 2,
#                 "fuel_type": "Premium Unleaded",
#                 "made_in": "USA",
#                 "make": "Mercedes-Benz",
#                 "model": "C-Class",
#                 "overall_height": "184.5",
#                 "overall_width": "56.9",
#                 "std_seating": "5",
#                 "transmission": "Automatic",
#                 "trim": "C300",
#                 "vehicle_type": "Car",
#                 "year": 2016
#             },
#             "carfax_1_owner": false,
#             "carfax_clean_title": false,
#             "data_source": "mc",
#             "dealer": {
#                 "city": "Redwood City",
# ...

# %%
# Pretty Print the output of the JSON
chevy_response = requests.get(chevy_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "listings": [
#         {
#             "build": {
#                 "body_type": "Sedan",
#                 "cylinders": 4,
#                 "doors": 4,
#                 "drivetrain": "RWD",
#                 "engine": "2.0L I4",
#                 "engine_block": "I",
#                 "engine_size": 2,
#                 "fuel_type": "Premium Unleaded",
#                 "made_in": "USA",
#                 "make": "Mercedes-Benz",
#                 "model": "C-Class",
#                 "overall_height": "184.5",
#                 "overall_width": "56.9",
#                 "std_seating": "5",
#                 "transmission": "Automatic",
#                 "trim": "C300",
#                 "vehicle_type": "Car",
#                 "year": 2016
#             },
#             "carfax_1_owner": false,
#             "carfax_clean_title": false,
#             "data_source": "mc",
#             "dealer": {
#                 "city": "Redwood City",
# ...

# %%
# Pretty Print the output of the JSON
honda_response = requests.get(honda_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "listings": [
#         {
#             "build": {
#                 "body_type": "Sedan",
#                 "cylinders": 4,
#                 "doors": 4,
#                 "drivetrain": "RWD",
#                 "engine": "2.0L I4",
#                 "engine_block": "I",
#                 "engine_size": 2,
#                 "fuel_type": "Premium Unleaded",
#                 "made_in": "USA",
#                 "make": "Mercedes-Benz",
#                 "model": "C-Class",
#                 "overall_height": "184.5",
#                 "overall_width": "56.9",
#                 "std_seating": "5",
#                 "transmission": "Automatic",
#                 "trim": "C300",
#                 "vehicle_type": "Car",
#                 "year": 2016
#             },
#             "carfax_1_owner": false,
#             "carfax_clean_title": false,
#             "data_source": "mc",
#             "dealer": {
#                 "city": "Redwood City",
# ...

# %%
# Pretty Print the output of the JSON
toyota_response = requests.get(toyota_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "listings": [
#         {
#             "build": {
#                 "body_type": "Sedan",
#                 "cylinders": 4,
#                 "doors": 4,
#                 "drivetrain": "RWD",
#                 "engine": "2.0L I4",
#                 "engine_block": "I",
#                 "engine_size": 2,
#                 "fuel_type": "Premium Unleaded",
#                 "made_in": "USA",
#                 "make": "Mercedes-Benz",
#                 "model": "C-Class",
#                 "overall_height": "184.5",
#                 "overall_width": "56.9",
#                 "std_seating": "5",
#                 "transmission": "Automatic",
#                 "trim": "C300",
#                 "vehicle_type": "Car",
#                 "year": 2016
#             },
#             "carfax_1_owner": false,
#             "carfax_clean_title": false,
#             "data_source": "mc",
#             "dealer": {
#                 "city": "Redwood City",
# ...

# %%
# Pretty Print the output of the JSON
lexus_response = requests.get(lexus_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "listings": [
#         {
#             "build": {
#                 "body_type": "Sedan",
#                 "cylinders": 4,
#                 "doors": 4,
#                 "drivetrain": "RWD",
#                 "engine": "2.0L I4",
#                 "engine_block": "I",
#                 "engine_size": 2,
#                 "fuel_type": "Premium Unleaded",
#                 "made_in": "USA",
#                 "make": "Mercedes-Benz",
#                 "model": "C-Class",
#                 "overall_height": "184.5",
#                 "overall_width": "56.9",
#                 "std_seating": "5",
#                 "transmission": "Automatic",
#                 "trim": "C300",
#                 "vehicle_type": "Car",
#                 "year": 2016
#             },
#             "carfax_1_owner": false,
#             "carfax_clean_title": false,
#             "data_source": "mc",
#             "dealer": {
#                 "city": "Redwood City",
# ...

# %%
# Pretty Print the output of the JSON
mercedes_response = requests.get(mercedes_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "listings": [
#         {
#             "build": {
#                 "body_type": "Sedan",
#                 "cylinders": 4,
#                 "doors": 4,
#                 "drivetrain": "RWD",
#                 "engine": "2.0L I4",
#                 "engine_block": "I",
#                 "engine_size": 2,
#                 "fuel_type": "Premium Unleaded",
#                 "made_in": "USA",
#                 "make": "Mercedes-Benz",
#                 "model": "C-Class",
#                 "overall_height": "184.5",
#                 "overall_width": "56.9",
#                 "std_seating": "5",
#                 "transmission": "Automatic",
#                 "trim": "C300",
#                 "vehicle_type": "Car",
#                 "year": 2016
#             },
#             "carfax_1_owner": false,
#             "carfax_clean_title": false,
#             "data_source": "mc",
#             "dealer": {
#                 "city": "Redwood City",
# ...

# %%
new_collection = db.new_cars

# %%
used_collection = db.used_cars

# %%
ca_collection = db.ca_cars

# %%
ny_collection = db.ny_cars

# %%
kia_collection = db.kia_cars

# %%
chevy_collection = db.chevy_cars

# %%
honda_collection = db.honda_cars

# %%
toyota_collection = db.toyota_cars

# %%
lexus_collection = db.lexus_cars

# %%
mercedes_collection = db.mercedes_cars

# %%
new = new_collection.insert_many(new_response)

# %%
used = used_collection.insert_many(used_response)

# %%
ca = ca_collection.insert_many(new_response)

# %%
ny = ny_collection.insert_many(ny_response)

# %%
kia = kia_collection.insert_one(kia_response)

# %%
chevy = chevy_collection.insert_one(chevy_response)

# %%
honda = honda_collection.insert_one(honda_response)

# %%
toyota = toyota_collection.insert_one(toyota_response)

# %%
lexus = lexus_collection.insert_one(lexus_response)

# %%
mercedes = mercedes_collection.insert_one(mercedes_response)
