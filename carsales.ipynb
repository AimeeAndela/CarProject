# %%
# Dependencies
import requests
import json
import pymongo
from config import api_key

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.classDB

# %%
# URL for GET requests to retrieve vehicle data
new_url = "https://marketcheck-prod.apigee.net/v2/popular/cars?api_key=E22Bwy9DWcFVH8VjBCYovVhuhmOoNIuG&car_type=new"

# %%
used_url = "https://marketcheck-prod.apigee.net/v2/popular/cars?api_key=E22Bwy9DWcFVH8VjBCYovVhuhmOoNIuG&car_type=used"

# %%
ca_url = "https://marketcheck-prod.apigee.net/v2/popular/cars?api_key=E22Bwy9DWcFVH8VjBCYovVhuhmOoNIuG&car_type=new&state=CA"

# %%
ny_url = "https://marketcheck-prod.apigee.net/v2/popular/cars?api_key=E22Bwy9DWcFVH8VjBCYovVhuhmOoNIuG&car_type=used&state=NY"

# %%
kia_url = "https://marketcheck-prod.apigee.net/v2/stats/car?api_key=E22Bwy9DWcFVH8VjBCYovVhuhmOoNIuG&car_type=new&ymm=2015|kia|rio"

# %%
chevy_url = "https://marketcheck-prod.apigee.net/v2/stats/car?api_key=E22Bwy9DWcFVH8VjBCYovVhuhmOoNIuG&car_type=new&ymm=2015|chevrolet|cruze"

# %%
honda_url = "https://marketcheck-prod.apigee.net/v2/stats/car?api_key=E22Bwy9DWcFVH8VjBCYovVhuhmOoNIuG&car_type=new&ymm=2015|honda|accord"

# %%
toyota_url = "https://marketcheck-prod.apigee.net/v2/stats/car?api_key=E22Bwy9DWcFVH8VjBCYovVhuhmOoNIuG&car_type=new&ymm=2015|toyota|camry"

# %%
bmw_url = "https://marketcheck-prod.apigee.net/v2/stats/car?api_key=E22Bwy9DWcFVH8VjBCYovVhuhmOoNIuG&car_type=new&ymm=2015|bmw|3-series"

# %%
mercedes_url = "https://marketcheck-prod.apigee.net/v2/stats/car?api_key=E22Bwy9DWcFVH8VjBCYovVhuhmOoNIuG&car_type=new&ymm=2015|mercedes-benz|a-class"

# %%
# Print the response object to the console
print(requests.get(new_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(used_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(ca_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(ny_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(kia_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(chevy_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(honda_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(toyota_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(bmw_url))
# Out:
# <Response [200]>

# %%
# Print the response object to the console
print(requests.get(mercedes_url))
# Out:
# <Response [422]>

# %%
# Retrieving data and converting it into JSON
print(requests.get(new_url).json())
# Out:
# [{'country': 'us', 'inventory_type': 'new', 'count': 102963, 'make': 'Ford', 'model': 'F-150', 'price_stats': {'geometric_mean': 43059, 'listings_count': 98390, 'min': 6250, 'median': 41831, 'population_standard_deviation': 26503, 'variance': 702382605, 'max': 7502019, 'mean': 44459, 'trimmed_mean': 43343, 'standard_deviation': 26503, 'iqr': 13504}, 'miles_stats': {'geometric_mean': 49, 'listings_count': 16935, 'min': 1, 'median': 16, 'population_standard_deviation': 8892, 'variance': 79076485, 'max': 730469, 'mean': 1381, 'trimmed_mean': 409, 'standard_deviation': 8892, 'iqr': 743}, 'dom_stats': {'geometric_mean': 86, 'listings_count': 102963, 'min': 1, 'median': 96, 'population_standard_deviation': 102, 'variance': 10365, 'max': 1464, 'mean': 126, 'trimmed_mean': 114, 'standard_deviation': 102, 'iqr': 140}}, {'country': 'us', 'inventory_type': 'new', 'count': 89329, 'make': 'Chevrolet', 'model': 'Silverado 1500', 'price_stats': {'geometric_mean': 40644, 'listings_count': 88061, 'mi
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(used_url).json())
# Out:
# [{'country': 'us', 'inventory_type': 'used', 'count': 102767, 'make': 'Ford', 'model': 'F-150', 'price_stats': {'geometric_mean': 22934, 'listings_count': 90156, 'min': 499, 'median': 26450, 'population_standard_deviation': 11368, 'variance': 129241702, 'max': 409905, 'mean': 25821, 'trimmed_mean': 25545, 'standard_deviation': 11368, 'iqr': 14195}, 'miles_stats': {'geometric_mean': 49392, 'listings_count': 98269, 'min': 1, 'median': 60062, 'population_standard_deviation': 57017, 'variance': 3250942079, 'max': 1406720, 'mean': 74231, 'trimmed_mean': 67610, 'standard_deviation': 57017, 'iqr': 75920}, 'dom_stats': {'geometric_mean': 68, 'listings_count': 102767, 'min': 1, 'median': 80, 'population_standard_deviation': 158, 'variance': 24894, 'max': 2429, 'mean': 124, 'trimmed_mean': 96, 'standard_deviation': 158, 'iqr': 119}}, {'country': 'us', 'inventory_type': 'used', 'count': 75449, 'make': 'Chevrolet', 'model': 'Silverado 1500', 'price_stats': {'geometric_mean': 22927, 'listings_cou
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(ca_url).json())
# Out:
# [{'country': 'us', 'inventory_type': 'new', 'state': 'CA', 'count': 11037, 'make': 'Honda', 'model': 'Accord', 'price_stats': {'geometric_mean': 27330, 'listings_count': 9692, 'min': 16509, 'median': 27110, 'population_standard_deviation': 3192, 'variance': 10185698, 'max': 63255, 'mean': 27504, 'trimmed_mean': 27137, 'standard_deviation': 3192, 'iqr': 3900}, 'miles_stats': {'geometric_mean': 6, 'listings_count': 3072, 'min': 1, 'median': 5, 'population_standard_deviation': 4101, 'variance': 16814922, 'max': 202430, 'mean': 154, 'trimmed_mean': 6, 'standard_deviation': 4101, 'iqr': 7}, 'dom_stats': {'geometric_mean': 50, 'listings_count': 11037, 'min': 1, 'median': 54, 'population_standard_deviation': 82, 'variance': 6660, 'max': 664, 'mean': 81, 'trimmed_mean': 67, 'standard_deviation': 82, 'iqr': 81}}, {'country': 'us', 'inventory_type': 'new', 'state': 'CA', 'count': 10732, 'make': 'Toyota', 'model': 'Camry', 'price_stats': {'geometric_mean': 27706, 'listings_count': 10312, 'min':
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(ny_url).json())
# Out:
# [{'country': 'us', 'inventory_type': 'used', 'state': 'NY', 'count': 2732, 'make': 'Honda', 'model': 'CR-V', 'price_stats': {'geometric_mean': 17174, 'listings_count': 2486, 'min': 2500, 'median': 18323, 'population_standard_deviation': 4697, 'variance': 22057200, 'max': 35999, 'mean': 17894, 'trimmed_mean': 17990, 'standard_deviation': 4697, 'iqr': 5805}, 'miles_stats': {'geometric_mean': 37226, 'listings_count': 2590, 'min': 2, 'median': 36343, 'population_standard_deviation': 36029, 'variance': 1298077746, 'max': 265976, 'mean': 48440, 'trimmed_mean': 43034, 'standard_deviation': 36029, 'iqr': 39966}, 'dom_stats': {'geometric_mean': 55, 'listings_count': 2732, 'min': 1, 'median': 61, 'population_standard_deviation': 158, 'variance': 25049, 'max': 1845, 'mean': 100, 'trimmed_mean': 72, 'standard_deviation': 158, 'iqr': 82}}, {'country': 'us', 'inventory_type': 'used', 'state': 'NY', 'count': 2713, 'make': 'Nissan', 'model': 'Rogue', 'price_stats': {'geometric_mean': 16410, 'listing
# ...

# %%
# Retrieving data and converting it into JSON
print(requests.get(kia_url).json())
# Out:
# {'price_stats': {'geometric_mean': 11499, 'min': 11498, 'median': 11498, 'population_standard_deviation': 0, 'variance': 0, 'max': 11498, 'mean': 11498, 'trimmed_mean': 11498, 'standard_deviation': 0, 'iqr': 0}, 'miles_stats': {'geometric_mean': 82781, 'min': 82780, 'median': 82780, 'population_standard_deviation': 0, 'variance': 0, 'max': 82780, 'mean': 82780, 'trimmed_mean': 82780, 'standard_deviation': 0, 'iqr': 0}, 'dom_stats': {'geometric_mean': 54, 'min': 53, 'median': 53, 'population_standard_deviation': 0, 'variance': 0, 'max': 53, 'mean': 53, 'trimmed_mean': 53, 'standard_deviation': 0, 'iqr': 0}, 'count': 1}

# %%
# Retrieving data and converting it into JSON
print(requests.get(chevy_url).json())
# Out:
# {'price_stats': {'geometric_mean': 9996, 'min': 9995, 'median': 9995, 'population_standard_deviation': 0, 'variance': 0, 'max': 9995, 'mean': 9995, 'trimmed_mean': 9995, 'standard_deviation': 0, 'iqr': 0}, 'miles_stats': {'geometric_mean': 39482, 'min': 39481, 'median': 39481, 'population_standard_deviation': 0, 'variance': 0, 'max': 39481, 'mean': 39481, 'trimmed_mean': 39481, 'standard_deviation': 0, 'iqr': 0}, 'dom_stats': {'geometric_mean': 528, 'min': 528, 'median': 528, 'population_standard_deviation': 0, 'variance': 0, 'max': 528, 'mean': 528, 'trimmed_mean': 528, 'standard_deviation': 0, 'iqr': 0}, 'count': 1}

# %%
# Retrieving data and converting it into JSON
print(requests.get(honda_url).json())
# Out:
# {'price_stats': {'geometric_mean': 15000, 'min': 14999, 'median': 14999, 'population_standard_deviation': 0, 'variance': 0, 'max': 14999, 'mean': 14999, 'trimmed_mean': 14999, 'standard_deviation': 0, 'iqr': 0}, 'miles_stats': {'geometric_mean': 62555, 'min': 62555, 'median': 62555, 'population_standard_deviation': 0, 'variance': 0, 'max': 62555, 'mean': 62555, 'trimmed_mean': 62555, 'standard_deviation': 0, 'iqr': 0}, 'dom_stats': {'geometric_mean': 51, 'min': 51, 'median': 51, 'population_standard_deviation': 0, 'variance': 0, 'max': 51, 'mean': 51, 'trimmed_mean': 51, 'standard_deviation': 0, 'iqr': 0}, 'count': 1}

# %%
# Retrieving data and converting it into JSON
print(requests.get(toyota_url).json())
# Out:
# {'price_stats': {'geometric_mean': 23337, 'min': 9991, 'median': 27169, 'population_standard_deviation': 9410, 'variance': 88530492, 'max': 34513, 'mean': 25290, 'trimmed_mean': 25290, 'standard_deviation': 9410, 'iqr': 15628}, 'miles_stats': {'geometric_mean': 159706, 'min': 159706, 'median': 159706, 'population_standard_deviation': 0, 'variance': 0, 'max': 159706, 'mean': 159706, 'trimmed_mean': 159706, 'standard_deviation': 0, 'iqr': 0}, 'dom_stats': {'geometric_mean': 137, 'min': 29, 'median': 126, 'population_standard_deviation': 437, 'variance': 190230, 'max': 1154, 'mean': 316, 'trimmed_mean': 316, 'standard_deviation': 437, 'iqr': 563}, 'count': 6}

# %%
# Retrieving data and converting it into JSON
print(requests.get(bmw_url).json())
# Out:
# {'price_stats': {'geometric_mean': 21000, 'min': 20999, 'median': 20999, 'population_standard_deviation': 0, 'variance': 0, 'max': 20999, 'mean': 20999, 'trimmed_mean': 20999, 'standard_deviation': 0, 'iqr': 0}, 'miles_stats': {'geometric_mean': 31805, 'min': 21690, 'median': 34163, 'population_standard_deviation': 17640, 'variance': 311151458, 'max': 46636, 'mean': 34163, 'trimmed_mean': 34163, 'standard_deviation': 17640, 'iqr': 24946}, 'dom_stats': {'geometric_mean': 594, 'min': 589, 'median': 594, 'population_standard_deviation': 8, 'variance': 50, 'max': 599, 'mean': 594, 'trimmed_mean': 594, 'standard_deviation': 8, 'iqr': 10}, 'count': 2}

# %%
# Retrieving data and converting it into JSON
print(requests.get(mercedes_url).json())
# Out:
# {'code': 422, 'message': 'us#new#2015#mercedes benz#a class not found'}

# %%
# Pretty Print the output of the JSON
response = requests.get(new_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "count": 102963,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 86,
#             "iqr": 140,
#             "listings_count": 102963,
#             "max": 1464,
#             "mean": 126,
#             "median": 96,
#             "min": 1,
#             "population_standard_deviation": 102,
#             "standard_deviation": 102,
#             "trimmed_mean": 114,
#             "variance": 10365
#         },
#         "inventory_type": "new",
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 49,
#             "iqr": 743,
#             "listings_count": 16935,
#             "max": 730469,
#             "mean": 1381,
#             "median": 16,
#             "min": 1,
#             "population_standard_deviation": 8892,
#             "standard_deviation": 8892,
#             "trimmed_mean": 409,
#             "variance": 79076485
#         },
#         "model": "F-150",
# ...

# %%
# Pretty Print the output of the JSON
response = requests.get(used_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "count": 102767,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 68,
#             "iqr": 119,
#             "listings_count": 102767,
#             "max": 2429,
#             "mean": 124,
#             "median": 80,
#             "min": 1,
#             "population_standard_deviation": 158,
#             "standard_deviation": 158,
#             "trimmed_mean": 96,
#             "variance": 24894
#         },
#         "inventory_type": "used",
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 49392,
#             "iqr": 75920,
#             "listings_count": 98269,
#             "max": 1406720,
#             "mean": 74231,
#             "median": 60062,
#             "min": 1,
#             "population_standard_deviation": 57017,
#             "standard_deviation": 57017,
#             "trimmed_mean": 67610,
#             "variance": 3250942079
#         },
#         "model": "F-150",
# ...

# %%
# Pretty Print the output of the JSON
response = requests.get(ca_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "count": 11037,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 50,
#             "iqr": 81,
#             "listings_count": 11037,
#             "max": 664,
#             "mean": 81,
#             "median": 54,
#             "min": 1,
#             "population_standard_deviation": 82,
#             "standard_deviation": 82,
#             "trimmed_mean": 67,
#             "variance": 6660
#         },
#         "inventory_type": "new",
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 3072,
#             "max": 202430,
#             "mean": 154,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 4101,
#             "standard_deviation": 4101,
#             "trimmed_mean": 6,
#             "variance": 16814922
#         },
#         "model": "Accord",
#         "price_stats": {
# ...

# %%
# Pretty Print the output of the JSON
response = requests.get(ny_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "count": 2732,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 55,
#             "iqr": 82,
#             "listings_count": 2732,
#             "max": 1845,
#             "mean": 100,
#             "median": 61,
#             "min": 1,
#             "population_standard_deviation": 158,
#             "standard_deviation": 158,
#             "trimmed_mean": 72,
#             "variance": 25049
#         },
#         "inventory_type": "used",
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 37226,
#             "iqr": 39966,
#             "listings_count": 2590,
#             "max": 265976,
#             "mean": 48440,
#             "median": 36343,
#             "min": 2,
#             "population_standard_deviation": 36029,
#             "standard_deviation": 36029,
#             "trimmed_mean": 43034,
#             "variance": 1298077746
#         },
#         "model": "CR-V",
# ...

# %%
# Pretty Print the output of the JSON
response = requests.get(kia_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "count": 1,
#     "dom_stats": {
#         "geometric_mean": 54,
#         "iqr": 0,
#         "max": 53,
#         "mean": 53,
#         "median": 53,
#         "min": 53,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 53,
#         "variance": 0
#     },
#     "miles_stats": {
#         "geometric_mean": 82781,
#         "iqr": 0,
#         "max": 82780,
#         "mean": 82780,
#         "median": 82780,
#         "min": 82780,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 82780,
#         "variance": 0
#     },
#     "price_stats": {
#         "geometric_mean": 11499,
#         "iqr": 0,
#         "max": 11498,
#         "mean": 11498,
#         "median": 11498,
#         "min": 11498,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 11498,
#         "variance": 0
#     }
# }

# %%
# Pretty Print the output of the JSON
response = requests.get(chevy_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "count": 1,
#     "dom_stats": {
#         "geometric_mean": 528,
#         "iqr": 0,
#         "max": 528,
#         "mean": 528,
#         "median": 528,
#         "min": 528,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 528,
#         "variance": 0
#     },
#     "miles_stats": {
#         "geometric_mean": 39482,
#         "iqr": 0,
#         "max": 39481,
#         "mean": 39481,
#         "median": 39481,
#         "min": 39481,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 39481,
#         "variance": 0
#     },
#     "price_stats": {
#         "geometric_mean": 9996,
#         "iqr": 0,
#         "max": 9995,
#         "mean": 9995,
#         "median": 9995,
#         "min": 9995,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 9995,
#         "variance": 0
#     }
# }

# %%
# Pretty Print the output of the JSON
response = requests.get(honda_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "count": 1,
#     "dom_stats": {
#         "geometric_mean": 51,
#         "iqr": 0,
#         "max": 51,
#         "mean": 51,
#         "median": 51,
#         "min": 51,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 51,
#         "variance": 0
#     },
#     "miles_stats": {
#         "geometric_mean": 62555,
#         "iqr": 0,
#         "max": 62555,
#         "mean": 62555,
#         "median": 62555,
#         "min": 62555,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 62555,
#         "variance": 0
#     },
#     "price_stats": {
#         "geometric_mean": 15000,
#         "iqr": 0,
#         "max": 14999,
#         "mean": 14999,
#         "median": 14999,
#         "min": 14999,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 14999,
#         "variance": 0
#     }
# }

# %%
# Pretty Print the output of the JSON
response = requests.get(toyota_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "count": 6,
#     "dom_stats": {
#         "geometric_mean": 137,
#         "iqr": 563,
#         "max": 1154,
#         "mean": 316,
#         "median": 126,
#         "min": 29,
#         "population_standard_deviation": 437,
#         "standard_deviation": 437,
#         "trimmed_mean": 316,
#         "variance": 190230
#     },
#     "miles_stats": {
#         "geometric_mean": 159706,
#         "iqr": 0,
#         "max": 159706,
#         "mean": 159706,
#         "median": 159706,
#         "min": 159706,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 159706,
#         "variance": 0
#     },
#     "price_stats": {
#         "geometric_mean": 23337,
#         "iqr": 15628,
#         "max": 34513,
#         "mean": 25290,
#         "median": 27169,
#         "min": 9991,
#         "population_standard_deviation": 9410,
#         "standard_deviation": 9410,
#         "trimmed_mean": 25290,
# ...

# %%
# Pretty Print the output of the JSON
response = requests.get(bmw_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "count": 2,
#     "dom_stats": {
#         "geometric_mean": 594,
#         "iqr": 10,
#         "max": 599,
#         "mean": 594,
#         "median": 594,
#         "min": 589,
#         "population_standard_deviation": 8,
#         "standard_deviation": 8,
#         "trimmed_mean": 594,
#         "variance": 50
#     },
#     "miles_stats": {
#         "geometric_mean": 31805,
#         "iqr": 24946,
#         "max": 46636,
#         "mean": 34163,
#         "median": 34163,
#         "min": 21690,
#         "population_standard_deviation": 17640,
#         "standard_deviation": 17640,
#         "trimmed_mean": 34163,
#         "variance": 311151458
#     },
#     "price_stats": {
#         "geometric_mean": 21000,
#         "iqr": 0,
#         "max": 20999,
#         "mean": 20999,
#         "median": 20999,
#         "min": 20999,
#         "population_standard_deviation": 0,
#         "standard_deviation": 0,
#         "trimmed_mean": 20999,
#         "variance": 0
# ...

# %%
# Pretty Print the output of the JSON
response = requests.get(mercedes_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "code": 422,
#     "message": "us#new#2015#mercedes benz#a class not found"
# }

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'classDB')

# %%
show collectionsdb.car_db.insert(
    {
       'response'    }
)
# Out:
#   File "<ipython-input-261-0d4075cafba6>", line 1
#     show collectionsdb.car_db.insert(
#                      ^
# SyntaxError: invalid syntax

# %%
db.createCollection("new")
